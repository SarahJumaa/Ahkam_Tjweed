# %%
from experta import *
from pyquran import *
from pyarabic import araby

# %%
class TarkekAlRaa(Fact):
    pass

class TafkhemAlRaa(Fact):
    pass

class Hams(Fact):
    pass

class Aistiela(Fact):
    pass 

class Ezhar(Fact):
    pass

class IdghaamWithGhunnah(Fact):
    pass

class IdghaamWithOutGhunnah(Fact):
    pass

class Ikhfa(Fact):
    pass

class Iqlab(Fact):
    pass

class GhunnahKamla(Fact):
    pass

class GhunnahNaqisa(Fact):
    pass

class IkhfaShafawe(Fact):
    pass

class EzharShafawe(Fact):
    pass

class IdghamShafawe(Fact):
    pass

class TafkhemLafzAljalala(Fact):
    pass

class TarqeqLafzAljalala(Fact):
    pass

class MadMoutasel(Fact):
    pass

class MadMounfasel(Fact):
    pass

class MadLazmKalemi(Fact):
    pass

class MadLazmHarfi(Fact):
    pass

class QalqalhKubra(Fact):
    pass

class QalqalhSura(Fact):
    pass

class IdgamMoutaganis(Fact):
    pass

class IdgamMoutaqareb(Fact):
    pass

class IdgamMoutamathel(Fact):
    pass

# %%
hams=['ت','ك','س','خ','ص','ش','ه','ث','ح','ف']
aistiela=['خ','ص','ض','غ','ط','ق','ظ']
Izhar = ['أ','ه','ع','ح','غ','خ','ؤ','ئ','ء','إ']
Idgam = ['ي','ر','م','ل','و','ن'] 
qalqaleh = ['ب','ط','ق','ج','د'] 
ghnah = ['ن','م']
Ikhfaa = ['ظ','ض','ت','ف','ز','ط','د','س','ق','ش','ج','ك','ث','ذ','ص']
IzharShafawi = ['ظ','ض','ت','ف','ز','ط','د','س','ق','ش','ج','ك','ث','ذ','ص', 'ي','ر','ل','و','ن','أ','ه','ع','ح','غ','خ','ؤ','ئ','ء','إ']
AhrfAlmad = ['ا','و','ي','ى']
Haraka = ['ُ','ِ','َ','ّ','ً','ٌ','ٍ']
LazmHarfi=['ص','ن','ق','حم','عسق','طه','طس','يس','الم','الر','طسم','المص','المر','كهيعص']
tafkhem=['خ','ص','ض','غ','ط','ق','ظ']

# %%
class AhkamWithAljazria(KnowledgeEngine):
    NumOfSoura=''
    NumOfAya='' 
    Aya=''
    
    def fun(self):
        print('أهلاً بكم في النظام الخبير الذي يقوم باستنتاج أحكام التجويد و بعض صفات الحروف من النص القرآني مع الاستشهاد بأبيات الجزرية وبيان سبب الحكم')
        print("\n") 
     
   
    @DefFacts()
    def initialfacts(self):
        yield Fact(action='accept')

    @Rule(Fact(action='accept'))
    def NumOfSoura (self):
        self.declare(Fact(NumOfSoura=input("من فضلك أدخل رقم السورة القرآنية ")))
            
    @Rule(Fact(action='accept') ,Fact(NumOfSoura= 'value' << W()))
    def NumOfAya (self,value):
        self.NumOfSoura=value
        self.declare(Fact(NumOfAya=input("من فضلك أدخل رقم الآية "))) 

    @Rule(Fact(action='accept') ,Fact(NumOfAya= 'value' << W()), Fact(NumOfSoura= W()))
    def NumOfAya2 (self,value):
        self.NumOfAya=value
        self.Aya = quran.get_verse(int(self.NumOfSoura),int (self.NumOfAya), with_tashkeel=True)
        
        print("\n")
        AyaTokenize=araby.tokenize(self.Aya)
        print("الآية: ",self.Aya,"\n")
        print(AyaTokenize)
        print("\n")
        
    @Rule()
    def AhkamAlraa(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize : 
            for z in x:
                if  AyaTokenize.index(x)<len(AyaTokenize) :

                    if  z=='ر' and (x[x.index(z)+1]=='َ' or (x[x.index(z)+1]=='ُ') or (x[x.index(z)+1]=='ٌ') or (x[x.index(z)+1]=='ا'and x[x.index(z)+2]=='ً')):
                        self.declare(TafkhemAlRaa(action='True'))
                        print (x +' : الراء مفخمة ')
                        print('السبب: لأنه يجب تفخيم الراء اذا كانت مفتوحة أو مضمومة أو إذا كانت ساكنة وجاء قبلها فتح أو ضم  ')
                        print(' البيت: وَالْخُلْفُ فِي فِرْقٍ لِكَسْرٍ يُوجَدُ    وَأَخْفِ تَكْرِيراً إِذَا تـُشَدَّدُ')
                        print("\n")
                    elif  z=='ر' and AyaTokenize[AyaTokenize.index(x)]=="فِرْقٍ":
                        self.declare(TarkekAlRaa(action='True'))
                        print(x +' : الراء مفخمة وقفاً....بينما وصلاً جواز الوجهين التفخيم والترقيق  ')
                        print('السبب: التفخيم حصرا في حالة الوقف لأنها ساكنة وقبلها كسر أصلي وبعدها حرف استعلاء ساكن  بينما جواز الوجهين وصلاً لأن الراء ساكنة وقبلها مكسور وبعدها حرف استعلاءمكسور  ')
                        print(' البيت: وَالْخُلْفُ فِي فِرْقٍ لِكَسْرٍ يُوجَدُ    وَأَخْفِ تَكْرِيراً إِذَا تـُشَدَّدُ')
                        print("\n")

                    elif  z=='ر' and (x[x.index(z)+1]=='ِ' or (x[x.index(z)+1]=='ٍ')):
                        self.declare(TarkekAlRaa(action='True'))
                        print (x +' : الراء مرققة ')
                        print('    السبب: لأنه يجب  ترقيق الراء اذا كانت مكسورة أو قبلها مكسور  ')
                        print('    البيت: وَرَقِّقِ الرَّاءَ إِذَا مَا كُسِرَتْ     كَذَاكَ بَعْدَ الْكَسْرِ حَيْثُ سـَكَنَتْ')
                        print(' البيت:إِن لَّمْ تَكُنْ مِنْ قَبْلِ حَرْفِ اسْتِعْلاَ     أَوْ كـَانَت الْكَسْرَةُ لَيْسَتْ أَصْلاَ')
                        print("\n")
                    elif  z=='ر' and ( araby.is_sukun(x[x.index(z)+1])) and ((x[x.index(z)-1]=='َ') or (x[x.index(z)-1]=='ُ')):
                        self.declare(TafkhemAlRaa(action='True'))
                        print (x +' : الراء مفخمة ')
                        print('السبب: لأنه يجب تفخيم الراء اذا كانت مفتوحة أو مضمومة أو إذا كانت ساكنة وجاء قبلها فتح أو ضم  ')
                        print(' البيت: وَالْخُلْفُ فِي فِرْقٍ لِكَسْرٍ يُوجَدُ    وَأَخْفِ تَكْرِيراً إِذَا تـُشَدَّدُ')
                        print("\n")
                    elif  z=='ر' and ( araby.is_sukun(x[x.index(z)+1])) and (x[x.index(z)-1]== 'ِ'):
                        self.declare(TarkekAlRaa(action='True'))
                        print (x +' : الراء مرققة ')
                        print('    السبب: لأنه يجب  ترقيق الراء اذا كانت مكسورة أو قبلها  مكسور  ')
                        print('     البيت: وَرَقِّقِ الرَّاءَ إِذَا مَا كُسِرَتْ     كَذَاكَ بَعْدَ الْكَسْرِ حَيْثُ سـَكَنَتْ')
                        print(' البيت: إِن لَّمْ تَكُنْ مِنْ قَبْلِ حَرْفِ اسْتِعْلاَ     أَوْ كـَانَت الْكَسْرَةُ لَيْسَتْ أَصْلاَ')
                        print("\n")
    
    @Rule()
    def Hams(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                if(x.index(z) <len(x)-2 ):
                    if ((araby.is_sukun(z) and (x[x.index(z)-1] in hams))):     
                        self.declare(Hams(action='True'))
                        print (x+' : الحرف الساكن من أحرف الهمس ')
                        print('          السبب: لأنه جاء حرف من أحرف الهمس في وسط الكلمة ')
                        print(' البيت:مهَمُوسُهَا(فَحَثّه شَخْص سَكَتْ)      شَدِيدُهَا لَفْظُ(أَجِدْ قَطِ بَكَتْ)')
                        print("\n")
                        break
                elif ((araby.is_sukun(z) and (x[x.index(z)-1] in hams))): 
                    self.declare(Hams(action='True'))
                    print (x+' :الحرف الساكن من أحرف الهمس ')
                    print('         السبب: لأنه جاء حرف من أحرف الهمس في نهاية الكلمة')
                    print(' البيت: مهَمُوسُهَا(فَحَثّه شَخْص سَكَتْ)      شَدِيدُهَا لَفْظُ(أَجِدْ قَطِ بَكَتْ)')
                    print("\n")
                    break
    @Rule()
    def Aistiela(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                if(x.index(z) <len(x)-2 ):
                    if ((x[x.index(z)-1] in aistiela)):     
                        self.declare(Aistiela(action='True'))
                        print (x+' :لدينا حرف استعلاء يجب تفخيمه  ')
                        print('                السبب: لأنه من صفات الحروف (خص ضغط قظ )التفخيم')
                        print( '  البيت: صِفاتَُهَا جَهْرٌ وَرِخْوٌ مُسْتَفِلْ          مُنْفَتِحٌ مُصْمَتَةٌ والضّد قُلْ ')
                        print( ' البيت:وَحَرْفَ الاِسْتِعْلاء فَخِّمْ,وَاخْصُصَا    الإِِطْباَقّ أقوْى نَحْوُ:قَاَلَ وَالْعَصَا')
                        print("\n")
                        break
                elif ( (x[x.index(z)] in aistiela)): 
                    self.declare(Aistiela(action='True'))
                    print (x+' :لدينا حرف استعلاء يجب تفخيمه ')
                    print('                السبب: لأنه من صفات الحروف (خص ضغط قظ )التفخيم')
                    print( '      البيت: صِفاتَُهَا جَهْرٌ وَرِخْوٌ مُسْتَفِلْ      مُنْفَتِحٌ مُصْمَتَةٌ والضّد قُلْ ') 
                    print( ' البيت:وَحَرْفَ الاِسْتِعْلاء فَخِّمْ,وَاخْصُصَا    الإِِطْباَقّ أقوْى نَحْوُ:قَاَلَ وَالْعَصَا')
                    print("\n")
                    break
    @Rule()
    def Qalqalh(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                if(x.index(z) <len(x)-2 ):
                    if ((araby.is_sukun(z) and (x[x.index(z)-1] in qalqaleh))):     
                        self.declare(QalqalhSura(action='True'))
                        print (x+' : قلقلة صغرى ')
                        print('    السبب: لأنه جاء حرف من أحرف القلقة(قطب جد) في وسط الكلمة')
                        print(' البيت: وَبَيِّنَنْ مُقَلْقَلاً إِنْ سَكَنَا     وَإِنْ يَكُنْ فِي الْوَقْفِ كَانَ أَبْيَـنَا')
                        print("\n")
                        break
                elif ((araby.is_sukun(z) and (x[x.index(z)-1] in qalqaleh))): 
                    self.declare(QalqalhKubra(action='True'))
                    print (x+' : قلقلة كبرى ')
                    print('السبب: لأنه جاء حرف من أحرف القلقلة(قطب جد) في نهاية الكلمة')
                    print(' البيت: وَبَيِّنَنْ مُقَلْقَلاً إِنْ سَكَنَا    وَإِنْ يَكُنْ فِي الْوَقْفِ كَانَ أَبْيَـنَا')
                    print("\n")
                    break
             
    @Rule()
    def  AhkamAltanwin(self):
        a=araby.tokenize(self.Aya)
        for x in a:
            for z in x:
                #أحكام التنوين
                if araby.is_tanwin(z) and a.index(x)+1 <len(a) :
                    if (a[a.index(x)+1][0] in Izhar) :
                        self.declare(Ezhar(action='True'))
                        self.declare(GhunnahNaqisa(action='True'))
                        print (x +' '+ a[a.index(x)+1]+' : إظهار ، غنة ناقصة')
                        print('                 السبب: لأنه جاء بعد التنوين حرف من أحرف الإظهار')
                        print('البيت: فَعِنْدَ حَرْفِ الحَلْقِ أَظْهِرْ وَادَّغِمْ     فِي اللاَّمِ وَالرَّا لاَ بِغُنَّةٍ لَزِمْا')
                        print("\n")
                    elif (a[a.index(x)+1][0] in Idgam) :
                        if(a[a.index(x)+1][0]=='ل' or a[a.index(x)+1][0]=='ر' ):
                            self.declare(IdghaamWithOutGhunnah(action='True'))
                            print(x +' '+ a[a.index(x)+1]+ ': إدغام بلا غنة')
                            print('          السبب: لأنه جاء بعد التنوين حرف من أحرف الإدغام بلاغنة')
                            print('البيت: فَعِنْدَ حَرْفِ الحَلْقِ أَظْهِرْ وَادَّغِمْ     فِي اللاَّمِ وَالرَّا لاَ بِغُنَّةٍ لَزِمْ')
                            print("\n")
                        elif(a[a.index(x)+1][0]=='ي' or a[a.index(x)+1][0]=='و' ):
                            self.declare(IdghaamWithGhunnah(action='True'))
                            self.declare(GhunnahKamla(action='True'))
                            print(x +' '+ a[a.index(x)+1]+ ': إدغام بغنة ، أكمل الغنن')
                            print('      السبب: لأنه جاء بعد التنوين حرف من أحرف الإدغام بغنة')
                            print(' البيت: وَأَدْغِمَنْ بِغُنَّةٍ في يُومــِنُ    إِلاَّ بِكِلْمَــةٍ كَـدُنْيَا عَنْوَنُو')
                            print("\n")
                        else :
                            self.declare(IdghaamWithGhunnah(action='True'))
                            print(x +' '+ a[a.index(x)+1]+ ': إدغام بغنة')
                            print('      السبب: لأنه جاء بعد التنوين حرف من أحرف الإدغام بغنة')
                            print(' البيت: وَأَدْغِمَنْ بِغُنَّةٍ في يُومــِنُ    إِلاَّ بِكِلْمَــةٍ كَـدُنْيَا عَنْوَنُو ')
                            print("\n")
                    elif a[a.index(x)+1][0]=='ب': 
                        self.declare(Iqlab(action='True'))
                        print(x +' '+ a[a.index(x)+1]+ ': إقلاب')
                        print('                          السبب: لأنه جاء بعد التنوين حرف الباء')
                        print(' البيت: وَاْلَقْلبُ عِنْدَ الْبَا بِغُنَّةٍ كذا    لاِخْفَاء لَدَى بَاقِي الحُرُوفِ أُخِذَا')
                        print("\n")
                    elif a[a.index(x)+1][0]in Ikhfaa :
                        self.declare(Ikhfa(action='True'))
                        self.declare(GhunnahKamla(action='True'))
                        print(x+' '+a[a.index(x)+1] +': إخفاء ، غنة كاملة')
                        print('                 السبب: لأنه جاء بعد التنوين حرف من أحرف الإخفاء')
                        print(' البيت: وَاْلَقْلبُ عِنْدَ الْبَا بِغُنَّةٍ كذا    لاِخْفَاء لَدَى بَاقِي الحُرُوفِ أُخِذَا')
                        print("\n")
                        
    @Rule()
    def AhkamAlnoonAlsakena(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                if  (z=='ن') or (araby.is_sukun(z) and x[x.index(z)-1]=='ن') :
                    #في كلمة واحدة
                    if(x.index(z)+1 <len(x) ):
                        if (x[x.index(z)+1] in Izhar) :
                            self.declare(Ezhar(action='True'))
                            self.declare(GhunnahNaqisa(action='True'))
                            print(x + ': إظهار ، غنة ناقصة')
                            print('           السبب: لأنه جاء بعد النون الساكنة حرف من أحرف الإظهار')
                            print(' البيت: فَعِنْدَ حَرْفِ الحَلْقِ أَظْهِرْ وَادَّغِمْ     فِي اللاَّمِ وَالرَّا لاَ بِغُنَّةٍ لَزِمْ')
                            print("\n")
                        elif (x[x.index(z)+1] in Idgam) :
                            if AyaTokenize[x[x.index(z)+1]]=='ل' or x[x.index(z)+1]=='ر' :
                                self.declare(IdghaamWithOutGhunnah(action='True'))
                                print(x + ': إدغام بلا غنة')
                                print('         السبب: لأنه جاء بعد النون الساكنة حرف من الإدغام بلا غنة')
                                print(' البيت: فَعِنْدَ حَرْفِ الحَلْقِ أَظْهِرْ وَادَّغِمْ     فِي اللاَّمِ وَالرَّا لاَ بِغُنَّةٍ لَزِمْ')
                                print("\n")
                            elif AyaTokenize[x[x.index(z)+1]]=='ي' or x[x.index(z)+1]=='و':
                                self.declare(IdghaamWithGhunnah(action='True'))
                                self.declare(GhunnahKamla(action='True'))
                                print(x + ': إدغام بغنة ، أكمل الغنن')
                                print('السبب: لأنه جاء بعد النون الساكنة حرف من أحرف الإدغام بغنة')
                                print(' البيت: وَأَدْغِمَنْ بِغُنَّةٍ في يُومــِنُ    إِلاَّ بِكِلْمَــةٍ كَـدُنْيَا عَنْوَنُو')
                                print("\n")
                            else : 
                                self.declare(IdghaamWithGhunnah(action='True'))
                                print(x + ': إدغام بغنة')
                                print('السبب: لأنه جاء بعد النون الساكنة حرف من أحرف الإدغام بغنة')
                                print(' البيت: وَأَدْغِمَنْ بِغُنَّةٍ في يُومــِنُ    إِلاَّ بِكِلْمَــةٍ كَـدُنْيَا عَنْوَنُو')
                                print("\n")
                        elif x[x.index(z)+1]=='ب': 
                            self.declare(Iqlab(action='True'))
                            print(x + ': إقلاب')
                            print('                    السبب: لأنه جاء بعد النون الساكنة حرف الباء')
                            print(' البيت: وَاْلَقْلبُ عِنْدَ الْبَا بِغُنَّةٍ كذا    لاِخْفَاء لَدَى بَاقِي الحُرُوفِ أُخِذَا')
                            print("\n")
                        elif x[x.index(z)+1] in Ikhfaa  :
                            self.declare(Ikhfa(action='True'))
                            self.declare(GhunnahKamla(action='True'))
                            print(x + ': إخفاء ، غنة كاملة' )
                            print('           السبب: لأنه جاء بعد النون الساكنة حرف من أحرف الإخفاء')
                            print(' البيت: وَاْلَقْلبُ عِنْدَ الْبَا بِغُنَّةٍ كذا    لاِخْفَاء لَدَى بَاقِي الحُرُوفِ أُخِذَا')
                            print("\n")

                    #في كلمتين        
                    else :
                        if (AyaTokenize[AyaTokenize.index(x)+1][0] in Izhar) :
                            self.declare(Ezhar(action='True'))
                            self.declare(GhunnahNaqisa(action='True'))
                            print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+ ': إظهار ، غنة ناقصة')
                            print('          السبب: لأنه جاء بعد النون الساكنة حرف من أحرف الإظهار')
                            print('البيت: فَعِنْدَ حَرْفِ الحَلْقِ أَظْهِرْ وَادَّغِمْ     فِي اللاَّمِ وَالرَّا لاَ بِغُنَّةٍ لَزِمْ')
                            print("\n")
                        elif (AyaTokenize[AyaTokenize.index(x)+1][0] in Idgam) :
                            if(AyaTokenize[AyaTokenize.index(x)+1][0]=='ل' or AyaTokenize[AyaTokenize.index(x)+1][0]=='ر' ):       
                                self.declare(IdghaamWithOutGhunnah(action='True'))
                                print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+ ': إدغام بلا غنة')
                                print('         السبب: لأنه جاء بعد النون الساكنة حرف من الإدغام بلا غنة')
                                print(' البيت: فَعِنْدَ حَرْفِ الحَلْقِ أَظْهِرْ وَادَّغِمْ     فِي اللاَّمِ وَالرَّا لاَ بِغُنَّةٍ لَزِمْ')
                                print("\n")
                            elif(AyaTokenize[AyaTokenize.index(x)+1][0]=='ي' or AyaTokenize[AyaTokenize.index(x)+1][0]=='و' ):
                                self.declare(IdghaamWithGhunnah(action='True'))
                                self.declare(GhunnahKamla(action='True'))
                                print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+ ': إدغام بغنة ، أكمل الغنن')
                                print('السبب: لأنه جاء بعد النون الساكنة حرف من أحرف الإدغام بغنة')
                                print(' البيت: وَأَدْغِمَنْ بِغُنَّةٍ في يُومــِنُ    إِلاَّ بِكِلْمَــةٍ كَـدُنْيَا عَنْوَنُو')
                                print("\n")
                            else:
                                self.declare(IdghaamWithGhunnah(action='True'))
                                print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1] + ': إدغام بغنة')
                                print('السبب: لأنه جاء بعد النون الساكنة حرف من أحرف الإدغام بغنة')
                                print(' البيت: وَأَدْغِمَنْ بِغُنَّةٍ في يُومــِنُ    إِلاَّ بِكِلْمَــةٍ كَـدُنْيَا عَنْوَنُو')
                                print("\n")
                        elif  AyaTokenize[AyaTokenize.index(x)+1][0]=='ب':  
                            self.declare(Iqlab(action='True'))
                            print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+ ': إقلاب')
                            print('                     السبب: لأنه جاء بعد النون الساكنة حرف البا')
                            print(' البيت: وَاْلَقْلبُ عِنْدَ الْبَا بِغُنَّةٍ كذا    لاِخْفَاء لَدَى بَاقِي الحُرُوفِ أُخِذَا')
                            print("\n")
                        else :
                            self.declare(Ikhfa(action='True'))
                            self.declare(GhunnahKamla(action='True'))                  
                            print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1] + ': إخفاء ، غنة كاملة')
                            print('           السبب: لأنه جاء بعد النون الساكنة حرف من أحرف الإخفاء')
                            print(' البيت: وَاْلَقْلبُ عِنْدَ الْبَا بِغُنَّةٍ كذا    لاِخْفَاء لَدَى بَاقِي الحُرُوفِ أُخِذَا')
                            print("\n")


    @Rule()
    def AhkamAlmemAlsakena(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                if z=='م' or (araby.is_sukun(z) and x[x.index(z)-1]=='م') :
                    #في كلمة واحدة
                    if(x.index(z)+1 <len(x) ):
                        if (x[x.index(z)+1] =='م') :
                            self.declare(IdghamShafawe(action='True'))
                            print(x + ': إدغام شفوي')
                            print('السبب: لأنه جاء بعد الميم الساكنة حرف من أحرف الإدغام الشفوي وهو حرف الميم ')
                            print('                 البيت: وأَظْهِرِ اْلغُنَّةَ مِنْ نُونٍ وَمِنْ    مِيمٍ إِذاَ مَا شُدِّدَا وَأَخْفِيَنْ')
                            print("\n")
                        elif x[x.index(z)+1]=='ب': 
                            self.declare(IkhfaShafawe(action='True'))
                            self.declare(GhunnahKamla(action='True'))
                            print(x + ': إخفاء شفوي ، غنة كاملة' )
                            print('السبب: لأنه جاء بعد الميم الساكنة حرف من أحرف الإخفاء الشفوي وهو حرف الباء ')
                            print('                 البيت: وأَظْهِرِ اْلغُنَّةَ مِنْ نُونٍ وَمِنْ    مِيمٍ إِذاَ مَا شُدِّدَا وَأَخْفِيَنْ')
                            print('             البيت:الْمِيمَ إِنْ تَسْكُنْ بِغُنَّةٍ لَدَى    بَاءٍ عَلَى المُخْتَارِ مِنْ أَهْلِ اْلأَدَا')
                            print("\n")
                        elif x[x.index(z)+1] in IzharShafawi  :
                            self.declare(EzharShafawe(action='True'))
                            self.declare(GhunnahNaqisa(action='True'))
                            print(x + ': إظهار شفوي ، غنة ناقصة')
                            print('   السبب: لأنه جاء بعد الميم الساكنة حرف من أحرف الإظهار الشفوي ')
                            print(' البيت: وَاظْهِرَنْهَا عِنْدَ بَاقِي اْلأَحْرُفِ    وَاحْذَرْ لَدى وَاوٍ وَفَا أنْ تَخْتَفِي')
                            print("\n")


                        #في كلمتين
                    else :
                        if(AyaTokenize.index(x)+1<len(AyaTokenize)):
                            if (AyaTokenize[AyaTokenize.index(x)+1][0] =='م') :
                                self.declare(IdghamShafawe(action='True'))    
                                print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+ ': إدغام شفوي')
                                print('السبب: لأنه جاء بعد الميم الساكنة حرف من أحرف الإدغام الشفوي وهو حرف الميم ')
                                print('                 البيت: وأَظْهِرِ اْلغُنَّةَ مِنْ نُونٍ وَمِنْ    مِيمٍ إِذاَ مَا شُدِّدَا وَأَخْفِيَنْ')
                                print("\n")
                            elif (AyaTokenize[AyaTokenize.index(x)+1][0] =='ب') :
                                self.declare(IkhfaShafawe(action='True'))
                                self.declare(GhunnahKamla(action='True'))    
                                print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+ ': إخفاء شفوي ، غنة كاملة')
                                print('السبب: لأنه جاء بعد الميم الساكنة حرف من أحرف الإخفاء الشفوي وهو حرف الباء')
                                print('                 البيت: وأَظْهِرِ اْلغُنَّةَ مِنْ نُونٍ وَمِنْ    مِيمٍ إِذاَ مَا شُدِّدَا وَأَخْفِيَنْ')
                                print('            البيت: الْمِيمَ إِنْ تَسْكُنْ بِغُنَّةٍ لَدَى    بَاءٍ عَلَى المُخْتَارِ مِنْ أَهْلِ اْلأَدَا')
                                print("\n")
                            else :
                                self.declare(EzharShafawe(action='True'))
                                self.declare(GhunnahNaqisa(action='True'))    
                                print(x +' '+ AyaTokenize[AyaTokenize.index(x)+1] + ' : إظهار شفوي ، غنة ناقصة')
                                print('   السبب: لأنه جاء بعد الميم الساكنة حرف من أحرف الإظهار الشفوي ')
                                print(' البيت: وَاظْهِرَنْهَا عِنْدَ بَاقِي اْلأَحْرُفِ    وَاحْذَرْ لَدى وَاوٍ وَفَا أنْ تَخْتَفِي')
                                print("\n")




    @Rule()
    def LafzAljalala(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
                #تفخيم وترقيق لفظ الجلالة
            if AyaTokenize[AyaTokenize.index(x)]=="اللَّهِ" or AyaTokenize[AyaTokenize.index(x)]=="اللَّهُ" or AyaTokenize[AyaTokenize.index(x)]=="اللَّهَ" :
                if AyaTokenize[AyaTokenize.index(x)-1][-1]=="ِ" or AyaTokenize[AyaTokenize.index(x)-1][-1]=="ٍ":
                    self.declare(TarqeqLafzAljalala(action='True'))
                    print(AyaTokenize[AyaTokenize.index(x)-1],AyaTokenize[AyaTokenize.index(x)]+' : لفظ جلالة مرقق')
                    print(' السبب: لأنه يرقق لفظ الجلالة إذا سبق بكسر أو سبق بحرف منون')
                    print(' البيت: فَرقَّقَنْ مُسْتَفِلاً مِـنْ أَحْـرُفِ     وَحَاذِرَنْ تَفْخيِمَ لَفْـظِ الأَلِفِ')
                    print('    البيت: كَهَمْزِ أَلْحَمْدُ أَعُوذُ إِهْــدِنَا    أللَّهَ ثُــمَّ لاَمَ لِلَّهِ لَنَــا')
                    print("\n")
                elif AyaTokenize[AyaTokenize.index(x)-1][-1]=="َ" or AyaTokenize[AyaTokenize.index(x)-1][-1]=="ً" or AyaTokenize[AyaTokenize.index(x)-1][-1]=="ُ" or AyaTokenize[AyaTokenize.index(x)-1][-1]=="ٌ":
                    self.declare(TarqeqLafzAljalala(action='True'))
                    print(AyaTokenize[AyaTokenize.index(x)-1],AyaTokenize[AyaTokenize.index(x)]+' : لفظ جلالة مفخم')
                    print('          السبب: لأنه يفخم لفظ الجلالة إذا سبق بفتح أو ضم')
                    print(' البيت: وَفَخِّم اللاَّمَ مِنِ اسْمِ اللَّهِ     عَنْ فَتْحٍ او ضَمٍ كَعَبْدُ اللَّـهِ')
                    print("\n")
        
                else:
                    if AyaTokenize[AyaTokenize.index(x)-1][-2]=="ِ" :
                        self.declare(TafkhemLafzAljalala(action='True'))
                        print(AyaTokenize[AyaTokenize.index(x)-1],AyaTokenize[AyaTokenize.index(x)]+' : لفظ جلالة مرقق')
                        print('  السبب: لأنه يرقق لفظ الجلالة إذا سبق بكسر أو سبق بحرف منون  ')
                        print(' البيت: فَرقَّقَنْ مُسْتَفِلاً مِـنْ أَحْـرُفِ       وَحَاذِرَنْ تَفْخيِمَ لَفْـظِ الأَلِفِ')
                        print('      البيت: كَهَمْزِ أَلْحَمْدُ أَعُوذُ إِهْــدِنَا    أللَّهَ ثُــمَّ لاَمَ لِلَّهِ لَنَــا')
                        print("\n")
                    else:
                        self.declare(TafkhemLafzAljalala(action='True'))
                        print(AyaTokenize[AyaTokenize.index(x)-1],AyaTokenize[AyaTokenize.index(x)]+' : لفظ جلالة مفخم')
                        print('          السبب: لأنه يفخم لفظ الجلالة إذا سبق بفتح أو ضم  ')
                        print(' البيت: وَفَخِّم اللاَّمَ مِنِ اسْمِ اللَّهِ     عَنْ فَتْحٍ او ضَمٍ كَعَبْدُ اللَّـهِ')
                        print("\n")

            elif (AyaTokenize[AyaTokenize.index(x)]=="لِلَّهِ" or AyaTokenize[AyaTokenize.index(x)]=="بِاللَّهِ"):
                self.declare(TarqeqLafzAljalala(action='True'))
                print(AyaTokenize[AyaTokenize.index(x)]+' : لفظ جلالة مرقق')
                print('السبب: لأنه يرقق لفظ الجلالة إذا سبق بكسر أو سبق بحرف منون  ')
                print(' البيت: فَرقَّقَنْ مُسْتَفِلاً مِـنْ أَحْـرُفِ     وَحَاذِرَنْ تَفْخيِمَ لَفْـظِ الأَلِفِ')
                print(' البيت: كَهَمْزِ أَلْحَمْدُ أَعُوذُ إِهْــدِنَا       أللَّهَ ثُــمَّ لاَمَ لِلَّهِ لَنَــا')
                print("\n")
            elif  (AyaTokenize[AyaTokenize.index(x)]=="تَاللَّهِ" or AyaTokenize[AyaTokenize.index(x)]=="وَاللَّهُ" or AyaTokenize[AyaTokenize.index(x)]=="وَاللَّهِ" or AyaTokenize[AyaTokenize.index(x)]=="فَوَاللَّهِ"):
                self.declare(TafkhemLafzAljalala(action='True'))
                print(AyaTokenize[AyaTokenize.index(x)]+' : لفظ جلالة مفخم')
                print('         السبب:  لأنه يفخم لفظ الجلالة إذا سبق بفتح أو ضم')
                print(' البيت: وَفَخِّم اللاَّمَ مِنِ اسْمِ اللَّهِ     عَنْ فَتْحٍ او ضَمٍ كَعَبْدُ اللَّـهِ')
                print("\n")

    @Rule()
    def Almodod(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                         #مد متصل 
                        if(x.index(z)+1<len(x)):
                            if ((z=='ي' and x[x.index(z)-1]=='ِ') or( z=='و' and x[x.index(z)-1]=='ُ') or( z=='ا' and x[x.index(z)-1]=='َ') or( z=='ى' and x[x.index(z)-1]=='َ')):
                                if araby.is_sukun(x[x.index(z)+1]) and araby.is_hamza(x[x.index(z)+2]):
                                    self.declare(MadMoutasel(action='True'))
                                    print (x + ' : مد واجب متصل ')
                                    print('       السبب: لأنه جاء حرف المد وبعده همز في كلمةٍ واحدة ')
                                    print(' البيت: وَوَاجِبٌ إنْ جاءَ قَبْلَ هَمْزَةِ    مُتَّصِلاً إِنْ جُمِعــَا بِكِلْمَـةِ')
                                    print("\n")
                                else:
                                    if( araby.is_hamza(x[x.index(z)+1])):
                                        self.declare(MadMoutasel(action='True'))
                                        print (x + ' : مد واجب متصل ')
                                        print('        السبب: لأنه جاء حرف المد وبعده همز في كلمةٍ واحد')
                                        print('  البيت:وَوَاجِبٌ إنْ جاءَ قَبْلَ هَمْزَةِ    مُتَّصِلاً إِنْ جُمِعــَا بِكِلْمَـةِ')
                                        print("\n")
                         #مد منفصل 
                        else:
                            if (z=='ي' and x[x.index(z)-1]=='ِ') or( z=='و' and x[x.index(z)-1]=='ُ') or( z=='ا' and x[x.index(z)-1]=='َ') or( z=='ى' and x[x.index(z)-1]=='َ'):
                                if AyaTokenize.index(x)+1 <len(AyaTokenize):
                                    if( araby.is_hamza(AyaTokenize[AyaTokenize.index(x)+1][0])):
                                        self.declare(MadMounfasel(action='True'))
                                        print(x+' ' + AyaTokenize[AyaTokenize.index(x)+1]+' : مد جائز منفصل ')
                                        print('السبب: لأنه جاء حرف المد في نهاية الكلمة الأولى وبعده همز في بداية الكلمة الثانية  ')
                                        print('  البيت: وَجَائزٌ إِذَا أَتَى مُنْفَصِلاَ    أَوْعَرَضَ السُّكُونُ وَقْفاٌ مُسْجَلاَ')
                                        print("\n")
    @Rule()
    def MadLazmHarfi(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            if x in LazmHarfi:
                self.declare(MadLazmHarfi(action='True'))
                print (x+ ' : مد لازم حرفي ')
                print(' السبب: لأنه جاء  بعد حرف المد في هجاء الحروف المقطعة حرف مدغم   ')
                print(' البيت:  فَلاَزِمٌ إِن جَاءَ بَعْدَ حَرْفِ مَدْ       سَاكِنَ حَالَيْنِ وَبِالطُّولِ يُمـَدْ')
                print("\n")
        
                
    @Rule()
    def MadLazmKalemi(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                if z in AhrfAlmad:
                    
                    if (x.index(z)-1>=0):
                        if((z=='ي' and x[x.index(z)-1]=='ِ') or( z=='و' and x[x.index(z)-1]=='ُ') or( z=='ا' and x[x.index(z)-1]=='َ') or( z=='ى' and x[x.index(z)-1]=='َ')) :
                            if x.index(z)+1<len(x):
                                if araby.is_sukun(x[x.index(z)+1]):
                                    if(x.index(z)+3<len(x) ):
                                        if  (x[x.index(z)+3]=='ّ'):
                                            self.declare(MadLazmKalemi(action='True'))
                                            print (x + ' : مد لازم كلمي مثقل ')
                                            print('                السبب: لأنه جاء حرف المد وبعده حرف ساكن مشدد  ')
                                            print('  البيت: فَلاَزِمٌ إِن جَاءَ بَعْدَ حَرْفِ مَدْ     سَاكِنَ حَالَيْنِ وَبِالطُّولِ يُمـَدْ')
                                            print("\n")
                                else:
                                    if x.index(z)+2<len(x):
                                        if (x[x.index(z)+2]=='ّ'):
                                            self.declare(MadLazmKalemi(action='True'))
                                            print (x + ' : مد لازم كلمي مثقل ')
                                            print('               السبب: لأنه جاء حرف المد وبعده حرف ساكن مشدد  ')
                                            print(' البيت: فَلاَزِمٌ إِن جَاءَ بَعْدَ حَرْفِ مَدْ     سَاكِنَ حَالَيْنِ وَبِالطُّولِ يُمـَدْ')
                                            print("\n")

    @Rule()
    def MadAred(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                if z in AhrfAlmad:
                     if (x.index(z)-1>=0):
                        if((z=='ي' and x[x.index(z)-1]=='ِ') or( z=='و' and x[x.index(z)-1]=='ُ') or( z=='ا' and x[x.index(z)-1]=='َ') or( z=='ى' and x[x.index(z)-1]=='َ')) :
                            if x.index(z)+1<len(x):
                                if araby.is_sukun(x[x.index(z)+1]):
                                    if(x.index(z)+3==len(x) or x.index(z)+2==len(x)):
                                        print (x,' : مد عارض للسكون في حال الوقف ')
                                        print('السبب: لأنه جاء حرف المد وبعده حرف ساكن سكوناً عارضاًبسبب الوقف  ')
                                        print(' البيت:   وَجَائزٌ إِذَا أَتَى مُنْفَصِلاَ         أَوْعَرَضَ السُّكُونُ وَقْفاٌ مُسْجَلاَ')
                                        print("\n")
                                elif x[x.index(z)+1] not in Haraka:
                                    if(x.index(z)+1==len(x) or x.index(z)+2==len(x)):
                                        print (x,' : مد عارض للسكون في حال الوقف ')
                                        print('السبب: لأنه جاء حرف المد وبعده حرف ساكن سكوناً عارضاًبسبب الوقف  ')
                                        print(' البيت:  وَجَائزٌ إِذَا أَتَى مُنْفَصِلاَ          أَوْعَرَضَ السُّكُونُ وَقْفاٌ مُسْجَلاَ')
                                        print("\n")

    @Rule()
    def IdgamHasabHAlsifat(self):
        AyaTokenize=araby.tokenize(self.Aya)
        for x in AyaTokenize:
            for z in x:
                if  AyaTokenize.index(x)+1 <len(AyaTokenize) :
                    if ( x[-1] == AyaTokenize[AyaTokenize.index(x)+1][0]  and not((x[-1] in AhrfAlmad))) :
                        self.declare(IdgamMoutamathel(action='True'))
                        print (x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+' : ادغام متماثل ')
                        print('           السبب: لأنه جاء حرفان متفقان في المخرج والصفة')
                        print(' البيت:وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ    أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')
                        print("\n")
                        break
                    if (x.index(z)+1 <len(x) ): 
                        if ( x[x.index(z)] == x[x.index(z)+1] and x != 'اللَّهِ' and x != 'اللَّهُ' and x !='اللَّهَ'):
                            self.declare(IdgamMoutamathel(action='True'))
                            print (x +' : في كلمة ادغام متماثل ')
                            print('           السبب: لأنه جاء حرفان متفقان في المخرج والصفة')
                            print(' البيت: وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ    أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')
                            print("\n")
                        if ( x[x.index(z)] == 'ق' and x[x.index(z)+1]=='ك'): 
                            self.declare(IdgamMoutaqareb(action='True'))
                            print (x +' : ادغام متقارب ')
                            print('           السبب: لأنه جاء حرفان متقاربان في المخرج والصفة  ')
                            print(' البيت:وَبَيِّنِ الإِطْبَاقَ مِنْ أَحَطتُ مَعْ    بَسَطتَ وَالخُلْفُ بِنَخْلُقكُّمْ وَقـَعْ')
                            print("\n")


                        if ( x[-1]=='ل'  and AyaTokenize[AyaTokenize.index(x)+1][0]=='ر'):
                            self.declare(IdgamMoutaqareb(action='True'))
                            print (x +' : ادغام متقارب ')
                            print('           السبب: لأنه جاء حرفان متقاربان في المخرج والصفة')
                            print(' البيت:وَبَيِّنِ الإِطْبَاقَ مِنْ أَحَطتُ مَعْ    بَسَطتَ وَالخُلْفُ بِنَخْلُقكُّمْ وَقـَعْ')
                            print("\n")

                        if ( x[-1]=='ب'  and AyaTokenize[AyaTokenize.index(x)+1][0]=='م'):
                            self.declare(IdgamMoutaganis(action='True'))
                            print (x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+' : ادغام متجانس ')
                            print('السبب: لأنه جاء حرفان متفقان  في المخرج ومختلفان ببعض الصفات  ')
                            print('  البيت: وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ      أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')
                            print("\n")

                        if ( x[-1]=='ت'  and AyaTokenize[AyaTokenize.index(x)+1][0]=='د'):
                            self.declare(IdgamMoutaganis(action='True'))
                            print (x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+' : ادغام متجانس ')
                            print('  السبب: لأنه جاء حرفان متفقان  في المخرج ومختلفان ببعض الصفات  ')
                            print(' البيت: وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ         أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')
                            print("\n")

                        if ( x[-1]=='د'  and AyaTokenize[AyaTokenize.index(x)+1][0]=='ت'):
                            self.declare(IdgamMoutaganis(action='True'))
                            print (x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+' : ادغام متجانس ')
                            print('السبب: لأنه جاء حرفان متفقان  في المخرج ومختلفان ببعض الصفات  ')
                            print(' البيت: وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ       أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')
                            print("\n")


                        if ( x[x.index(z)] == 'د' and x[x.index(z)+1]=='ت'): 
                            self.declare(IdgamMoutaganis(action='True'))
                            print (x +' : ادغام متجانس ')
                            print('السبب: لأنه جاء حرفان متفقان  في المخرج ومختلفان ببعض الصفات  ')
                            print(' البيت: وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ       أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')
                            print("\n")

                        if ( x[-1]=='ت'  and AyaTokenize[AyaTokenize.index(x)+1][0]=='ط'):
                            self.declare(IdgamMoutaganis(action='True'))
                            print (x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+' : ادغام متجانس ')
                            print('السبب: لأنه جاء حرفان متفقان  في المخرج ومختلفان ببعض الصفات  ')
                            print('  البيت: وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ      أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')
                            print("\n")

                        if ( x[-1]=='ذ'  and AyaTokenize[AyaTokenize.index(x)+1][0]=='ظ'):
                            self.declare(IdgamMoutaganis(action='True'))
                            print (x +' '+ AyaTokenize[AyaTokenize.index(x)+1]+' : ادغام متجانس ')
                            print('السبب: لأنه جاء حرفان متفقان  في المخرج ومختلفان ببعض الصفات  ')
                            print('   البيت: وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ     أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')
                            print("\n")

                        if ( x[x.index(z)] == 'ط' and x[x.index(z)+1]=='ت'): 
                            self.declare(IdgamMoutaganis(action='True'))
                            print (x +' : ادغام متجانس ')
                            print('السبب: لأنه جاء حرفان متفقان  في المخرج ومختلفات ببعض الصفات  ')
                            print('  البيت: وَأَوَّلَىْ مِثْلٍ وَجِنْسٍ إنْ سَكَنْ      أَدْغِمْ كَقُل رَّبِّ وَبَلَ لاَ وَأَبِـنْ')

# %%
engine=AhkamWithAljazria()
engine.fun()
engine.reset()
engine.run()
# Out:
# أهلاً بكم في النظام الخبير الذي يقوم باستنتاج أحكام التجويد و بعض صفات الحروف من النص القرآني مع الاستشهاد بأبيات الجزرية وبيان سبب الحكم
#
#
# من فضلك أدخل رقم السورة القرآنية 54
# من فضلك أدخل رقم الآية 17
#
#
# الآية:  وَلَقَدْ يَسَّرْنَا الْقُرْءَانَ لِلذِّكْرِ فَهَلْ مِن مُّدَّكِرٍ
#
# ['وَلَقَدْ', 'يَسَّرْنَا', 'الْقُرْءَانَ', 'لِلذِّكْرِ', 'فَهَلْ', 'مِن', 'مُّدَّكِرٍ']
#
#
# لِلذِّكْرِ : الحرف الساكن من أحرف الهمس
#           السبب: لأنه جاء حرف من أحرف الهمس في وسط الكلمة
#  البيت:مهَمُوسُهَا(فَحَثّه شَخْص سَكَتْ)      شَدِيدُهَا لَفْظُ(أَجِدْ قَطِ بَكَتْ)
#
#
# يَسَّرْنَا : الراء مفخمة
# السبب: لأنه يجب تفخيم الراء اذا كانت مفتوحة أو مضمومة أو إذا كانت ساكنة وجاء قبلها فتح أو ضم
#  البيت: وَالْخُلْفُ فِي فِرْقٍ لِكَسْرٍ يُوجَدُ    وَأَخْفِ تَكْرِيراً إِذَا تـُشَدَّدُ
#
#
# الْقُرْءَانَ : الراء مفخمة
# السبب: لأنه يجب تفخيم الراء اذا كانت مفتوحة أو مضمومة أو إذا كانت ساكنة وجاء قبلها فتح أو ضم
# ...
